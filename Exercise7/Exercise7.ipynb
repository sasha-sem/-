# %% [markdown]
# # **Практическая работа №7. Использование автоэнкодера для решения задач семантической сегментации. Часть 1**

# %% [markdown]
# # Этап 1. Выбор и обработка исходных данных. Разделение на обучающую и тестовую выборку

# %% [markdown]
# # Разделение данных по папкам на обучающую и проверочную выборку
#
#
# Ниже представлен Код для разделения папки на train и val.
# После создания новых папок переименуйте их и расположите в формате, приведенном ниже, для использования для семантической сегментации с помощью генераторов данных.
#
# [Документация](https://pypi.org/project/split-folders/)

# %% [markdown]
# ### Подсказка

# %%
# %pip install split-folders
# %pip install patchify
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: split-folders in c:\users\user\appdata\roaming\python\python39\site-packages (0.5.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: patchify in c:\users\user\appdata\roaming\python\python39\site-packages (0.2.3)
# Requirement already satisfied: numpy<2,>=1 in c:\users\user\appdata\roaming\python\python39\site-packages (from patchify) (1.24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from PIL import Image
import cv2
from patchify import patchify
import numpy as np

# %%
root_directory = r'C:\Users\User\Documents\GitHub\NeuralNetworkExercises\Exercise7\data\Semantic segmentation dataset'
patch_size = 256

# %%
image_dataset = []  
for path, subdirs, files in os.walk(root_directory):
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'images':   
        images = os.listdir(path)
        for i, image_name in enumerate(images):  
            if image_name.endswith(".jpg"):   
                image = cv2.imread(os.path.join(path, image_name), 1)  
                SIZE_X = (image.shape[1]//patch_size)*patch_size 
                SIZE_Y = (image.shape[0]//patch_size)*patch_size  
                image = image[0:SIZE_X, 0:SIZE_Y]
       
                patches_img = patchify(image, (patch_size, patch_size, 3), step=patch_size)
        
                for i in range(patches_img.shape[0]):
                    for j in range(patches_img.shape[1]):
                        
                        single_patch_img = patches_img[i,j,:,:]
                        single_patch_img = single_patch_img[0]

                        tile_name = path.split(os.path.sep)[-2].replace(' ', '_')                             
                        patch_filename =  os.path.splitext(image_name)[0] + f'_{tile_name}' + "_patch_" + str(i) + '_' + str(j) + ".jpg"
                        patch_path = os.path.join(root_directory, "Images", patch_filename)
                        cv2.imwrite(patch_path, single_patch_img)

# %%
mask_dataset = []  
for path, subdirs, files in os.walk(root_directory):
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'masks': 
        masks = os.listdir(path) 
    
        for i, mask_name in enumerate(masks):  
            if mask_name.endswith(".png"):  
               
                mask = cv2.imread(os.path.join(path, mask_name), 1)
                SIZE_X = (mask.shape[1]//patch_size)*patch_size
                SIZE_Y = (mask.shape[0]//patch_size)*patch_size
                mask = mask[0:SIZE_X, 0:SIZE_Y]
                patches_mask = patchify(mask, (patch_size, patch_size, 3), step=patch_size)
        
                for i in range(patches_mask.shape[0]):
                    for j in range(patches_mask.shape[1]):
                        
                        single_patch_mask = patches_mask[i,j,:,:]
                        single_patch_mask = single_patch_mask[0]

                        tile_name = path.split(os.path.sep)[-2].replace(' ', '_')                             
                        patch_filename =  os.path.splitext(mask_name)[0] + f'_{tile_name}' + "_patch_" + str(i) + '_' + str(j) + ".png"
                        patch_path = os.path.join(root_directory, "Masks", patch_filename)
                        cv2.imwrite(patch_path, single_patch_mask)

# %%
import splitfolders  # or import split_folders

input_folder = r'C:\Users\User\Documents\GitHub\NeuralNetworkExercises\Exercise7\data\Semantic segmentation dataset'
output_folder = r'C:\Users\User\Documents\GitHub\NeuralNetworkExercises\Exercise7\data\data_for_training_and_testing'

splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.75, .25), group_prefix=None) # default values
# Out:
# Copying files: 2106 files [00:09, 219.76 files/s]

# %% [markdown]
# Структура конечных папок для генератора (ImageDataGenerator()):
#
# (После разделения на папки, нужно разместить вручную или написать для этого специальную функцию, например, используя модуль shutil)
#
#
#
# ```
# dataset
#         train_image
#                     train
#         train_mask
#                     train
#         val_image
#                     val
#         val_mask
#                     val
# ```

# %% [markdown]
# #.

# %%
for root, dirs, files in os.walk('./data'):
    level = root.replace('./data', '').count(os.sep)
    indent = ' ' * 4 * (level)
    print('{}{}/'.format(indent, os.path.basename(root)))
    subindent = ' ' * 4 * (level + 1)
    if len(files) == 0:
        continue

    print('{}{} files'.format(subindent, len(files)))
# Out:
# data/
#     train_image/
#         train/
#             789 files
#     train_mask/
#         train/
#             789 files
#     val_image/
#         val/
#             264 files
#     val_mask/
#         val/
#             264 files

# %%
train_img_dir = r'.\data\train_image\train'
train_mask_dir = r'.\data\train_mask\train'

img_list = sorted(os.listdir(train_img_dir))
msk_list = sorted(os.listdir(train_mask_dir))

num_images = len(os.listdir(train_img_dir))

# %%
import random
from matplotlib import pyplot as plt

img_num = random.randint(0, num_images-1)

img_for_plot = cv2.imread(os.path.join(train_img_dir, img_list[img_num]))
img_for_plot = cv2.cvtColor(img_for_plot, cv2.COLOR_BGR2RGB)

mask_for_plot =cv2.imread(os.path.join(train_mask_dir, msk_list[img_num]))
mask_for_plot = cv2.cvtColor(mask_for_plot, cv2.COLOR_BGR2RGB)

fig=plt.figure(figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
 
figure, axis = plt.subplots(1, 2)

axis[0].imshow(img_for_plot, cmap=plt.get_cmap('gray'),vmin=0,vmax=100)
axis[0].set_title('Image')

axis[1].imshow(mask_for_plot)
axis[1].set_title('Mask')

plt.show()

fig=plt.figure(figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
 
figure, axis = plt.subplots(1, 3)

axis[0].imshow(img_for_plot[:,:,0])
axis[0].set_title('Image_Ch=1')

axis[1].imshow(img_for_plot[:,:,1])
axis[1].set_title('Image_Ch=2')

axis[2].imshow(img_for_plot[:,:,2])
axis[2].set_title('Image_Ch=3')

# Combine all the operations and display
plt.show()

fig=plt.figure(figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
 
figure, axis = plt.subplots(1, 3)

axis[0].imshow(mask_for_plot[:,:,0])
axis[0].set_title("Mask_Ch=1")

axis[1].imshow(mask_for_plot[:,:,1])
axis[1].set_title("Mask_Ch=2")

axis[2].imshow(mask_for_plot[:,:,2])
axis[2].set_title("Mask_Ch=3")

plt.show()

# %% [markdown]
# # Этап 2. Предобработка обучающей и валидационной выборки. Разработка архитектуры модели

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow import keras
from matplotlib import pyplot as plt
import segmentation_models as sm
from keras.metrics import MeanIoU
from keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
Building = np.array((60, 16, 152))
Land = np.array((132, 41, 246))
Road = np.array((110, 193, 228))
Vegetation = np.array((254, 221, 58))
Water = np.array((226, 169, 41))
Unlabeled = np.array((155, 155, 155))

# %%
def rgb_to_2D_label(label):
    if len(label.shape) == 3: 
        label = label[:,:,:3]
    if len(label.shape) == 4: 
        label = label[:,:,:,:3]

    label_seg = np.zeros(label.shape,dtype=np.uint8)
    label_seg [np.all(label == Building,axis=-1)] = 0
    label_seg [np.all(label==Land,axis=-1)] = 1
    label_seg [np.all(label==Road,axis=-1)] = 2
    label_seg [np.all(label==Vegetation,axis=-1)] = 3
    label_seg [np.all(label==Water,axis=-1)] = 4
    label_seg [np.all(label==Unlabeled,axis=-1)] = 5


    if len(label.shape) == 3: 
        label_seg = label_seg[:,:,0]
    if len(label.shape) == 4: 
        label_seg = label_seg[:,:,:,0]
        
    return label_seg

scaler = MinMaxScaler()
BACKBONE = 'resnet34'
preprocess_input = sm.get_preprocessing(BACKBONE)

def preprocess_data(img, mask, num_class):
    img = scaler.fit_transform(img.reshape(-1, img.shape[-1])).reshape(img.shape)
    img = preprocess_input(img) 
    mask = rgb_to_2D_label(mask)
    mask = to_categorical(mask, num_class)
      
    return (img, mask)

# %%
seed=24
batch_size= 16
n_classes=6

# %%
from keras.preprocessing.image import ImageDataGenerator
def trainGenerator(train_img_path, train_mask_path, num_class):
    
    img_data_gen_args = dict(horizontal_flip=True,
                      vertical_flip=True)
    
    image_datagen = ImageDataGenerator(**img_data_gen_args)
    mask_datagen = ImageDataGenerator(**img_data_gen_args)
    
    image_generator = image_datagen.flow_from_directory(
        train_img_path,
        class_mode = None,
        batch_size = batch_size,
        seed = seed)
    
    mask_generator = mask_datagen.flow_from_directory(
        train_mask_path,
        class_mode = None,
        batch_size = batch_size,
        seed = seed)
    
    train_generator = zip(image_generator, mask_generator)
    
    for (img, mask) in train_generator:
        img, mask = preprocess_data(img, mask, num_class)
        yield (img, mask)

# %%
train_img_path = r'.\data\train_image'
train_mask_path = r'.\data\train_mask'
train_img_gen = trainGenerator(train_img_path, train_mask_path, num_class=6)

val_img_path = r'.\data\val_image'
val_mask_path = r'.\data\val_mask'
val_img_gen = trainGenerator(val_img_path, val_mask_path, num_class=6)

# %%
num_train_imgs = len(os.listdir(r'.\data\train_image\train'))
num_val_images = len(os.listdir(r'.\data\val_image\val'))

steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %% [markdown]
# # Этап 3. Обучение модели

# %% [markdown]
# * Изучите техническую докуентацию по работе с модулем [Segmentation Models](https://segmentation-models.readthedocs.io/en/latest/tutorial.html)
#
# * Последовательно обучите несколько моделей, используя при этом разные [функции потерь ](https://segmentation-models.readthedocs.io/en/latest/api.html#losses)
#
# > [Реализация всех имеющихся в модуле функций потерь на GIT разработчиков](https://github.com/qubvel/segmentation_models/blob/master/segmentation_models/losses.py)
#
# * При обучении используйте несколько метрик [метрик](https://segmentation-models.readthedocs.io/en/latest/api.html#metrics), определив их в массиве.
#
#
#
# Пример:
#
# ```
# metrics = ['accuracy', sm.metrics.iou_score]
#
# model.compile('Adam', loss=sm.losses.categorical_focal_jaccard_loss, metrics=metrics)
# ```
# > [Реализация всех имеющихся в модуле метрик на GIT разработчиков](https://github.com/qubvel/segmentation_models/blob/master/segmentation_models/metrics.py)

# %% [markdown]
# ## Модель 1
# Функция потерь **Сategorical Focal Jaccard Loss**

# %%
metrics = ['accuracy', sm.metrics.iou_score, sm.metrics.FScore()]
model_1 = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation='softmax')

model_1.compile(optimizer='adam', loss=sm.losses.categorical_focal_jaccard_loss, metrics=metrics)
model_1.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, None, None,  0           []
#                                  3)]
#
#  bn_data (BatchNormalization)   (None, None, None,   9           ['data[0][0]']
#                                 3)
#
#  zero_padding2d_136 (ZeroPaddin  (None, None, None,   0          ['bn_data[0][0]']
#  g2D)                           3)
#
#  conv0 (Conv2D)                 (None, None, None,   9408        ['zero_padding2d_136[0][0]']
#                                 64)
#
#  bn0 (BatchNormalization)       (None, None, None,   256         ['conv0[0][0]']
#                                 64)
#
#  relu0 (Activation)             (None, None, None,   0           ['bn0[0][0]']
#                                 64)
#
#  zero_padding2d_137 (ZeroPaddin  (None, None, None,   0          ['relu0[0][0]']
#  g2D)                           64)
#
#  pooling0 (MaxPooling2D)        (None, None, None,   0           ['zero_padding2d_137[0][0]']
#                                 64)
#
#  stage1_unit1_bn1 (BatchNormali  (None, None, None,   256        ['pooling0[0][0]']
#  zation)                        64)
#
#  stage1_unit1_relu1 (Activation  (None, None, None,   0          ['stage1_unit1_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_138 (ZeroPaddin  (None, None, None,   0          ['stage1_unit1_relu1[0][0]']
#  g2D)                           64)
#
#  stage1_unit1_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_138[0][0]']
#                                 64)
#
#  stage1_unit1_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit1_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit1_relu2 (Activation  (None, None, None,   0          ['stage1_unit1_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_139 (ZeroPaddin  (None, None, None,   0          ['stage1_unit1_relu2[0][0]']
#  g2D)                           64)
#
#  stage1_unit1_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_139[0][0]']
#                                 64)
#
#  stage1_unit1_sc (Conv2D)       (None, None, None,   4096        ['stage1_unit1_relu1[0][0]']
#                                 64)
#
#  add_64 (Add)                   (None, None, None,   0           ['stage1_unit1_conv2[0][0]',
#                                 64)                               'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, None, None,   256        ['add_64[0][0]']
#  zation)                        64)
#
#  stage1_unit2_relu1 (Activation  (None, None, None,   0          ['stage1_unit2_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_140 (ZeroPaddin  (None, None, None,   0          ['stage1_unit2_relu1[0][0]']
#  g2D)                           64)
#
#  stage1_unit2_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_140[0][0]']
#                                 64)
#
#  stage1_unit2_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit2_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit2_relu2 (Activation  (None, None, None,   0          ['stage1_unit2_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_141 (ZeroPaddin  (None, None, None,   0          ['stage1_unit2_relu2[0][0]']
#  g2D)                           64)
#
#  stage1_unit2_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_141[0][0]']
#                                 64)
#
#  add_65 (Add)                   (None, None, None,   0           ['stage1_unit2_conv2[0][0]',
#                                 64)                               'add_64[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, None, None,   256        ['add_65[0][0]']
#  zation)                        64)
#
#  stage1_unit3_relu1 (Activation  (None, None, None,   0          ['stage1_unit3_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_142 (ZeroPaddin  (None, None, None,   0          ['stage1_unit3_relu1[0][0]']
#  g2D)                           64)
#
#  stage1_unit3_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_142[0][0]']
#                                 64)
#
#  stage1_unit3_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit3_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit3_relu2 (Activation  (None, None, None,   0          ['stage1_unit3_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_143 (ZeroPaddin  (None, None, None,   0          ['stage1_unit3_relu2[0][0]']
#  g2D)                           64)
#
#  stage1_unit3_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_143[0][0]']
#                                 64)
#
#  add_66 (Add)                   (None, None, None,   0           ['stage1_unit3_conv2[0][0]',
#                                 64)                               'add_65[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, None, None,   256        ['add_66[0][0]']
#  zation)                        64)
#
#  stage2_unit1_relu1 (Activation  (None, None, None,   0          ['stage2_unit1_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_144 (ZeroPaddin  (None, None, None,   0          ['stage2_unit1_relu1[0][0]']
#  g2D)                           64)
#
#  stage2_unit1_conv1 (Conv2D)    (None, None, None,   73728       ['zero_padding2d_144[0][0]']
#                                 128)
#
#  stage2_unit1_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit1_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit1_relu2 (Activation  (None, None, None,   0          ['stage2_unit1_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_145 (ZeroPaddin  (None, None, None,   0          ['stage2_unit1_relu2[0][0]']
#  g2D)                           128)
#
#  stage2_unit1_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_145[0][0]']
#                                 128)
#
#  stage2_unit1_sc (Conv2D)       (None, None, None,   8192        ['stage2_unit1_relu1[0][0]']
#                                 128)
#
#  add_67 (Add)                   (None, None, None,   0           ['stage2_unit1_conv2[0][0]',
#                                 128)                              'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, None, None,   512        ['add_67[0][0]']
#  zation)                        128)
#
#  stage2_unit2_relu1 (Activation  (None, None, None,   0          ['stage2_unit2_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_146 (ZeroPaddin  (None, None, None,   0          ['stage2_unit2_relu1[0][0]']
#  g2D)                           128)
#
#  stage2_unit2_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_146[0][0]']
#                                 128)
#
#  stage2_unit2_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit2_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit2_relu2 (Activation  (None, None, None,   0          ['stage2_unit2_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_147 (ZeroPaddin  (None, None, None,   0          ['stage2_unit2_relu2[0][0]']
#  g2D)                           128)
#
#  stage2_unit2_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_147[0][0]']
#                                 128)
#
#  add_68 (Add)                   (None, None, None,   0           ['stage2_unit2_conv2[0][0]',
#                                 128)                              'add_67[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, None, None,   512        ['add_68[0][0]']
#  zation)                        128)
#
#  stage2_unit3_relu1 (Activation  (None, None, None,   0          ['stage2_unit3_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_148 (ZeroPaddin  (None, None, None,   0          ['stage2_unit3_relu1[0][0]']
#  g2D)                           128)
#
#  stage2_unit3_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_148[0][0]']
#                                 128)
#
#  stage2_unit3_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit3_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit3_relu2 (Activation  (None, None, None,   0          ['stage2_unit3_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_149 (ZeroPaddin  (None, None, None,   0          ['stage2_unit3_relu2[0][0]']
#  g2D)                           128)
#
#  stage2_unit3_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_149[0][0]']
#                                 128)
#
#  add_69 (Add)                   (None, None, None,   0           ['stage2_unit3_conv2[0][0]',
#                                 128)                              'add_68[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, None, None,   512        ['add_69[0][0]']
#  zation)                        128)
#
#  stage2_unit4_relu1 (Activation  (None, None, None,   0          ['stage2_unit4_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_150 (ZeroPaddin  (None, None, None,   0          ['stage2_unit4_relu1[0][0]']
#  g2D)                           128)
#
#  stage2_unit4_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_150[0][0]']
#                                 128)
#
#  stage2_unit4_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit4_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit4_relu2 (Activation  (None, None, None,   0          ['stage2_unit4_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_151 (ZeroPaddin  (None, None, None,   0          ['stage2_unit4_relu2[0][0]']
#  g2D)                           128)
#
#  stage2_unit4_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_151[0][0]']
#                                 128)
#
#  add_70 (Add)                   (None, None, None,   0           ['stage2_unit4_conv2[0][0]',
#                                 128)                              'add_69[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, None, None,   512        ['add_70[0][0]']
#  zation)                        128)
#
#  stage3_unit1_relu1 (Activation  (None, None, None,   0          ['stage3_unit1_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_152 (ZeroPaddin  (None, None, None,   0          ['stage3_unit1_relu1[0][0]']
#  g2D)                           128)
#
#  stage3_unit1_conv1 (Conv2D)    (None, None, None,   294912      ['zero_padding2d_152[0][0]']
#                                 256)
#
#  stage3_unit1_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit1_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit1_relu2 (Activation  (None, None, None,   0          ['stage3_unit1_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_153 (ZeroPaddin  (None, None, None,   0          ['stage3_unit1_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit1_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_153[0][0]']
#                                 256)
#
#  stage3_unit1_sc (Conv2D)       (None, None, None,   32768       ['stage3_unit1_relu1[0][0]']
#                                 256)
#
#  add_71 (Add)                   (None, None, None,   0           ['stage3_unit1_conv2[0][0]',
#                                 256)                              'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, None, None,   1024       ['add_71[0][0]']
#  zation)                        256)
#
#  stage3_unit2_relu1 (Activation  (None, None, None,   0          ['stage3_unit2_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_154 (ZeroPaddin  (None, None, None,   0          ['stage3_unit2_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit2_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_154[0][0]']
#                                 256)
#
#  stage3_unit2_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit2_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit2_relu2 (Activation  (None, None, None,   0          ['stage3_unit2_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_155 (ZeroPaddin  (None, None, None,   0          ['stage3_unit2_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit2_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_155[0][0]']
#                                 256)
#
#  add_72 (Add)                   (None, None, None,   0           ['stage3_unit2_conv2[0][0]',
#                                 256)                              'add_71[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, None, None,   1024       ['add_72[0][0]']
#  zation)                        256)
#
#  stage3_unit3_relu1 (Activation  (None, None, None,   0          ['stage3_unit3_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_156 (ZeroPaddin  (None, None, None,   0          ['stage3_unit3_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit3_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_156[0][0]']
#                                 256)
#
#  stage3_unit3_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit3_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit3_relu2 (Activation  (None, None, None,   0          ['stage3_unit3_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_157 (ZeroPaddin  (None, None, None,   0          ['stage3_unit3_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit3_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_157[0][0]']
#                                 256)
#
#  add_73 (Add)                   (None, None, None,   0           ['stage3_unit3_conv2[0][0]',
#                                 256)                              'add_72[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, None, None,   1024       ['add_73[0][0]']
#  zation)                        256)
#
#  stage3_unit4_relu1 (Activation  (None, None, None,   0          ['stage3_unit4_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_158 (ZeroPaddin  (None, None, None,   0          ['stage3_unit4_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit4_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_158[0][0]']
#                                 256)
#
#  stage3_unit4_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit4_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit4_relu2 (Activation  (None, None, None,   0          ['stage3_unit4_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_159 (ZeroPaddin  (None, None, None,   0          ['stage3_unit4_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit4_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_159[0][0]']
#                                 256)
#
#  add_74 (Add)                   (None, None, None,   0           ['stage3_unit4_conv2[0][0]',
#                                 256)                              'add_73[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, None, None,   1024       ['add_74[0][0]']
#  zation)                        256)
#
#  stage3_unit5_relu1 (Activation  (None, None, None,   0          ['stage3_unit5_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_160 (ZeroPaddin  (None, None, None,   0          ['stage3_unit5_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit5_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_160[0][0]']
#                                 256)
#
#  stage3_unit5_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit5_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit5_relu2 (Activation  (None, None, None,   0          ['stage3_unit5_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_161 (ZeroPaddin  (None, None, None,   0          ['stage3_unit5_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit5_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_161[0][0]']
#                                 256)
#
#  add_75 (Add)                   (None, None, None,   0           ['stage3_unit5_conv2[0][0]',
#                                 256)                              'add_74[0][0]']
#
#  stage3_unit6_bn1 (BatchNormali  (None, None, None,   1024       ['add_75[0][0]']
#  zation)                        256)
#
#  stage3_unit6_relu1 (Activation  (None, None, None,   0          ['stage3_unit6_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_162 (ZeroPaddin  (None, None, None,   0          ['stage3_unit6_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit6_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_162[0][0]']
#                                 256)
#
#  stage3_unit6_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit6_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit6_relu2 (Activation  (None, None, None,   0          ['stage3_unit6_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_163 (ZeroPaddin  (None, None, None,   0          ['stage3_unit6_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit6_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_163[0][0]']
#                                 256)
#
#  add_76 (Add)                   (None, None, None,   0           ['stage3_unit6_conv2[0][0]',
#                                 256)                              'add_75[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, None, None,   1024       ['add_76[0][0]']
#  zation)                        256)
#
#  stage4_unit1_relu1 (Activation  (None, None, None,   0          ['stage4_unit1_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_164 (ZeroPaddin  (None, None, None,   0          ['stage4_unit1_relu1[0][0]']
#  g2D)                           256)
#
#  stage4_unit1_conv1 (Conv2D)    (None, None, None,   1179648     ['zero_padding2d_164[0][0]']
#                                 512)
#
#  stage4_unit1_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit1_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit1_relu2 (Activation  (None, None, None,   0          ['stage4_unit1_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_165 (ZeroPaddin  (None, None, None,   0          ['stage4_unit1_relu2[0][0]']
#  g2D)                           512)
#
#  stage4_unit1_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_165[0][0]']
#                                 512)
#
#  stage4_unit1_sc (Conv2D)       (None, None, None,   131072      ['stage4_unit1_relu1[0][0]']
#                                 512)
#
#  add_77 (Add)                   (None, None, None,   0           ['stage4_unit1_conv2[0][0]',
#                                 512)                              'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, None, None,   2048       ['add_77[0][0]']
#  zation)                        512)
#
#  stage4_unit2_relu1 (Activation  (None, None, None,   0          ['stage4_unit2_bn1[0][0]']
#  )                              512)
#
#  zero_padding2d_166 (ZeroPaddin  (None, None, None,   0          ['stage4_unit2_relu1[0][0]']
#  g2D)                           512)
#
#  stage4_unit2_conv1 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_166[0][0]']
#                                 512)
#
#  stage4_unit2_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit2_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit2_relu2 (Activation  (None, None, None,   0          ['stage4_unit2_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_167 (ZeroPaddin  (None, None, None,   0          ['stage4_unit2_relu2[0][0]']
#  g2D)                           512)
#
#  stage4_unit2_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_167[0][0]']
#                                 512)
#
#  add_78 (Add)                   (None, None, None,   0           ['stage4_unit2_conv2[0][0]',
#                                 512)                              'add_77[0][0]']
#
#  stage4_unit3_bn1 (BatchNormali  (None, None, None,   2048       ['add_78[0][0]']
#  zation)                        512)
#
#  stage4_unit3_relu1 (Activation  (None, None, None,   0          ['stage4_unit3_bn1[0][0]']
#  )                              512)
#
#  zero_padding2d_168 (ZeroPaddin  (None, None, None,   0          ['stage4_unit3_relu1[0][0]']
#  g2D)                           512)
#
#  stage4_unit3_conv1 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_168[0][0]']
#                                 512)
#
#  stage4_unit3_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit3_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit3_relu2 (Activation  (None, None, None,   0          ['stage4_unit3_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_169 (ZeroPaddin  (None, None, None,   0          ['stage4_unit3_relu2[0][0]']
#  g2D)                           512)
#
#  stage4_unit3_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_169[0][0]']
#                                 512)
#
#  add_79 (Add)                   (None, None, None,   0           ['stage4_unit3_conv2[0][0]',
#                                 512)                              'add_78[0][0]']
#
#  bn1 (BatchNormalization)       (None, None, None,   2048        ['add_79[0][0]']
#                                 512)
#
#  relu1 (Activation)             (None, None, None,   0           ['bn1[0][0]']
#                                 512)
#
#  decoder_stage0_upsampling (UpS  (None, None, None,   0          ['relu1[0][0]']
#  ampling2D)                     512)
#
#  decoder_stage0_concat (Concate  (None, None, None,   0          ['decoder_stage0_upsampling[0][0]
#  nate)                          768)                             ',
#                                                                   'stage4_unit1_relu1[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, None, None,   1769472     ['decoder_stage0_concat[0][0]']
#                                 256)
#
#  decoder_stage0a_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0a_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0a_relu (Activati  (None, None, None,   0          ['decoder_stage0a_bn[0][0]']
#  on)                            256)
#
#  decoder_stage0b_conv (Conv2D)  (None, None, None,   589824      ['decoder_stage0a_relu[0][0]']
#                                 256)
#
#  decoder_stage0b_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0b_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0b_relu (Activati  (None, None, None,   0          ['decoder_stage0b_bn[0][0]']
#  on)                            256)
#
#  decoder_stage1_upsampling (UpS  (None, None, None,   0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)                     256)
#
#  decoder_stage1_concat (Concate  (None, None, None,   0          ['decoder_stage1_upsampling[0][0]
#  nate)                          384)                             ',
#                                                                   'stage3_unit1_relu1[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, None, None,   442368      ['decoder_stage1_concat[0][0]']
#                                 128)
#
#  decoder_stage1a_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1a_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1a_relu (Activati  (None, None, None,   0          ['decoder_stage1a_bn[0][0]']
#  on)                            128)
#
#  decoder_stage1b_conv (Conv2D)  (None, None, None,   147456      ['decoder_stage1a_relu[0][0]']
#                                 128)
#
#  decoder_stage1b_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1b_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1b_relu (Activati  (None, None, None,   0          ['decoder_stage1b_bn[0][0]']
#  on)                            128)
#
#  decoder_stage2_upsampling (UpS  (None, None, None,   0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)                     128)
#
#  decoder_stage2_concat (Concate  (None, None, None,   0          ['decoder_stage2_upsampling[0][0]
#  nate)                          192)                             ',
#                                                                   'stage2_unit1_relu1[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, None, None,   110592      ['decoder_stage2_concat[0][0]']
#                                 64)
#
#  decoder_stage2a_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2a_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2a_relu (Activati  (None, None, None,   0          ['decoder_stage2a_bn[0][0]']
#  on)                            64)
#
#  decoder_stage2b_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage2a_relu[0][0]']
#                                 64)
#
#  decoder_stage2b_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2b_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2b_relu (Activati  (None, None, None,   0          ['decoder_stage2b_bn[0][0]']
#  on)                            64)
#
#  decoder_stage3_upsampling (UpS  (None, None, None,   0          ['decoder_stage2b_relu[0][0]']
#  ampling2D)                     64)
#
#  decoder_stage3_concat (Concate  (None, None, None,   0          ['decoder_stage3_upsampling[0][0]
#  nate)                          128)                             ',
#                                                                   'relu0[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage3_concat[0][0]']
#                                 32)
#
#  decoder_stage3a_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3a_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3a_relu (Activati  (None, None, None,   0          ['decoder_stage3a_bn[0][0]']
#  on)                            32)
#
#  decoder_stage3b_conv (Conv2D)  (None, None, None,   9216        ['decoder_stage3a_relu[0][0]']
#                                 32)
#
#  decoder_stage3b_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3b_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3b_relu (Activati  (None, None, None,   0          ['decoder_stage3b_bn[0][0]']
#  on)                            32)
#
#  decoder_stage4_upsampling (UpS  (None, None, None,   0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     32)
#
#  decoder_stage4a_conv (Conv2D)  (None, None, None,   4608        ['decoder_stage4_upsampling[0][0]
#                                 16)                              ']
#
#  decoder_stage4a_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4a_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4a_relu (Activati  (None, None, None,   0          ['decoder_stage4a_bn[0][0]']
#  on)                            16)
#
#  decoder_stage4b_conv (Conv2D)  (None, None, None,   2304        ['decoder_stage4a_relu[0][0]']
#                                 16)
#
#  decoder_stage4b_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4b_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4b_relu (Activati  (None, None, None,   0          ['decoder_stage4b_bn[0][0]']
#  on)                            16)
#
#  final_conv (Conv2D)            (None, None, None,   870         ['decoder_stage4b_relu[0][0]']
#                                 6)
#
#  softmax (Activation)           (None, None, None,   0           ['final_conv[0][0]']
#                                 6)
#
# ==================================================================================================
# Total params: 24,456,879
# Trainable params: 24,439,529
# Non-trainable params: 17,350
# __________________________________________________________________________________________________

# %%
history_1=model_1.fit(
          train_img_gen,
          steps_per_epoch=steps_per_epoch,
          epochs=100,
          verbose=1,
          validation_steps=val_steps_per_epoch,
          validation_data=val_img_gen)
# Out:
# Found 789 images belonging to 1 classes.
# Found 789 images belonging to 1 classes.
# Epoch 1/100
# 49/49 [==============================] - ETA: 0s - loss: 0.7288 - accuracy: 0.6773 - iou_score: 0.3062 - f1-score: 0.4083Found 264 images belonging to 1 classes.
# Found 264 images belonging to 1 classes.
# 49/49 [==============================] - 36s 509ms/step - loss: 0.7288 - accuracy: 0.6773 - iou_score: 0.3062 - f1-score: 0.4083 - val_loss: 1.3285 - val_accuracy: 0.3589 - val_iou_score: 0.0850 - val_f1-score: 0.1312
# Epoch 2/100
# 49/49 [==============================] - 16s 314ms/step - loss: 0.5847 - accuracy: 0.7810 - iou_score: 0.4539 - f1-score: 0.5683 - val_loss: 1.3561 - val_accuracy: 0.1193 - val_iou_score: 0.0212 - val_f1-score: 0.0375
# Epoch 3/100
# 49/49 [==============================] - 15s 317ms/step - loss: 0.5525 - accuracy: 0.8013 - iou_score: 0.4818 - f1-score: 0.5950 - val_loss: 0.9903 - val_accuracy: 0.5528 - val_iou_score: 0.0959 - val_f1-score: 0.1287
# Epoch 4/100
# 49/49 [==============================] - 16s 320ms/step - loss: 0.5234 - accuracy: 0.8145 - iou_score: 0.5113 - f1-score: 0.6209 - val_loss: 0.9915 - val_accuracy: 0.5573 - val_iou_score: 0.0982 - val_f1-score: 0.1321
# Epoch 5/100
# 49/49 [==============================] - 16s 324ms/step - loss: 0.5157 - accuracy: 0.8186 - iou_score: 0.5172 - f1-score: 0.6278 - val_loss: 1.0195 - val_accuracy: 0.5581 - val_iou_score: 0.0943 - val_f1-score: 0.1221
# Epoch 6/100
# 49/49 [==============================] - 25s 524ms/step - loss: 0.5173 - accuracy: 0.8213 - iou_score: 0.5122 - f1-score: 0.6174 - val_loss: 1.0139 - val_accuracy: 0.5583 - val_iou_score: 0.0947 - val_f1-score: 0.1231
# Epoch 7/100
# 49/49 [==============================] - 15s 310ms/step - loss: 0.5098 - accuracy: 0.8278 - iou_score: 0.5239 - f1-score: 0.6308 - val_loss: 1.0985 - val_accuracy: 0.1804 - val_iou_score: 0.0464 - val_f1-score: 0.0812
# Epoch 8/100
# 49/49 [==============================] - 15s 314ms/step - loss: 0.4982 - accuracy: 0.8296 - iou_score: 0.5327 - f1-score: 0.6388 - val_loss: 1.0419 - val_accuracy: 0.5623 - val_iou_score: 0.0942 - val_f1-score: 0.1208

# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, None, None,  0           []
#                                  3)]
#
#  bn_data (BatchNormalization)   (None, None, None,   9           ['data[0][0]']
#                                 3)
#
#  zero_padding2d_170 (ZeroPaddin  (None, None, None,   0          ['bn_data[0][0]']
#  g2D)                           3)
#
#  conv0 (Conv2D)                 (None, None, None,   9408        ['zero_padding2d_170[0][0]']
#                                 64)
#
#  bn0 (BatchNormalization)       (None, None, None,   256         ['conv0[0][0]']
#                                 64)
#
#  relu0 (Activation)             (None, None, None,   0           ['bn0[0][0]']
#                                 64)
#
#  zero_padding2d_171 (ZeroPaddin  (None, None, None,   0          ['relu0[0][0]']
#  g2D)                           64)
#
#  pooling0 (MaxPooling2D)        (None, None, None,   0           ['zero_padding2d_171[0][0]']
#                                 64)
#
#  stage1_unit1_bn1 (BatchNormali  (None, None, None,   256        ['pooling0[0][0]']
#  zation)                        64)
#
#  stage1_unit1_relu1 (Activation  (None, None, None,   0          ['stage1_unit1_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_172 (ZeroPaddin  (None, None, None,   0          ['stage1_unit1_relu1[0][0]']
#  g2D)                           64)
#
#  stage1_unit1_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_172[0][0]']
#                                 64)
#
#  stage1_unit1_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit1_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit1_relu2 (Activation  (None, None, None,   0          ['stage1_unit1_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_173 (ZeroPaddin  (None, None, None,   0          ['stage1_unit1_relu2[0][0]']
#  g2D)                           64)
#
#  stage1_unit1_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_173[0][0]']
#                                 64)
#
#  stage1_unit1_sc (Conv2D)       (None, None, None,   4096        ['stage1_unit1_relu1[0][0]']
#                                 64)
#
#  add_80 (Add)                   (None, None, None,   0           ['stage1_unit1_conv2[0][0]',
#                                 64)                               'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, None, None,   256        ['add_80[0][0]']
#  zation)                        64)
#
#  stage1_unit2_relu1 (Activation  (None, None, None,   0          ['stage1_unit2_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_174 (ZeroPaddin  (None, None, None,   0          ['stage1_unit2_relu1[0][0]']
#  g2D)                           64)
#
#  stage1_unit2_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_174[0][0]']
#                                 64)
#
#  stage1_unit2_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit2_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit2_relu2 (Activation  (None, None, None,   0          ['stage1_unit2_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_175 (ZeroPaddin  (None, None, None,   0          ['stage1_unit2_relu2[0][0]']
#  g2D)                           64)
#
#  stage1_unit2_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_175[0][0]']
#                                 64)
#
#  add_81 (Add)                   (None, None, None,   0           ['stage1_unit2_conv2[0][0]',
#                                 64)                               'add_80[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, None, None,   256        ['add_81[0][0]']
#  zation)                        64)
#
#  stage1_unit3_relu1 (Activation  (None, None, None,   0          ['stage1_unit3_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_176 (ZeroPaddin  (None, None, None,   0          ['stage1_unit3_relu1[0][0]']
#  g2D)                           64)
#
#  stage1_unit3_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_176[0][0]']
#                                 64)
#
#  stage1_unit3_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit3_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit3_relu2 (Activation  (None, None, None,   0          ['stage1_unit3_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_177 (ZeroPaddin  (None, None, None,   0          ['stage1_unit3_relu2[0][0]']
#  g2D)                           64)
#
#  stage1_unit3_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_177[0][0]']
#                                 64)
#
#  add_82 (Add)                   (None, None, None,   0           ['stage1_unit3_conv2[0][0]',
#                                 64)                               'add_81[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, None, None,   256        ['add_82[0][0]']
#  zation)                        64)
#
#  stage2_unit1_relu1 (Activation  (None, None, None,   0          ['stage2_unit1_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_178 (ZeroPaddin  (None, None, None,   0          ['stage2_unit1_relu1[0][0]']
#  g2D)                           64)
#
#  stage2_unit1_conv1 (Conv2D)    (None, None, None,   73728       ['zero_padding2d_178[0][0]']
#                                 128)
#
#  stage2_unit1_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit1_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit1_relu2 (Activation  (None, None, None,   0          ['stage2_unit1_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_179 (ZeroPaddin  (None, None, None,   0          ['stage2_unit1_relu2[0][0]']
#  g2D)                           128)
#
#  stage2_unit1_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_179[0][0]']
#                                 128)
#
#  stage2_unit1_sc (Conv2D)       (None, None, None,   8192        ['stage2_unit1_relu1[0][0]']
#                                 128)
#
#  add_83 (Add)                   (None, None, None,   0           ['stage2_unit1_conv2[0][0]',
#                                 128)                              'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, None, None,   512        ['add_83[0][0]']
#  zation)                        128)
#
#  stage2_unit2_relu1 (Activation  (None, None, None,   0          ['stage2_unit2_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_180 (ZeroPaddin  (None, None, None,   0          ['stage2_unit2_relu1[0][0]']
#  g2D)                           128)
#
#  stage2_unit2_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_180[0][0]']
#                                 128)
#
#  stage2_unit2_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit2_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit2_relu2 (Activation  (None, None, None,   0          ['stage2_unit2_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_181 (ZeroPaddin  (None, None, None,   0          ['stage2_unit2_relu2[0][0]']
#  g2D)                           128)
#
#  stage2_unit2_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_181[0][0]']
#                                 128)
#
#  add_84 (Add)                   (None, None, None,   0           ['stage2_unit2_conv2[0][0]',
#                                 128)                              'add_83[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, None, None,   512        ['add_84[0][0]']
#  zation)                        128)
#
#  stage2_unit3_relu1 (Activation  (None, None, None,   0          ['stage2_unit3_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_182 (ZeroPaddin  (None, None, None,   0          ['stage2_unit3_relu1[0][0]']
#  g2D)                           128)
#
#  stage2_unit3_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_182[0][0]']
#                                 128)
#
#  stage2_unit3_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit3_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit3_relu2 (Activation  (None, None, None,   0          ['stage2_unit3_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_183 (ZeroPaddin  (None, None, None,   0          ['stage2_unit3_relu2[0][0]']
#  g2D)                           128)
#
#  stage2_unit3_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_183[0][0]']
#                                 128)
#
#  add_85 (Add)                   (None, None, None,   0           ['stage2_unit3_conv2[0][0]',
#                                 128)                              'add_84[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, None, None,   512        ['add_85[0][0]']
#  zation)                        128)
#
#  stage2_unit4_relu1 (Activation  (None, None, None,   0          ['stage2_unit4_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_184 (ZeroPaddin  (None, None, None,   0          ['stage2_unit4_relu1[0][0]']
#  g2D)                           128)
#
#  stage2_unit4_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_184[0][0]']
#                                 128)
#
#  stage2_unit4_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit4_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit4_relu2 (Activation  (None, None, None,   0          ['stage2_unit4_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_185 (ZeroPaddin  (None, None, None,   0          ['stage2_unit4_relu2[0][0]']
#  g2D)                           128)
#
#  stage2_unit4_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_185[0][0]']
#                                 128)
#
#  add_86 (Add)                   (None, None, None,   0           ['stage2_unit4_conv2[0][0]',
#                                 128)                              'add_85[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, None, None,   512        ['add_86[0][0]']
#  zation)                        128)
#
#  stage3_unit1_relu1 (Activation  (None, None, None,   0          ['stage3_unit1_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_186 (ZeroPaddin  (None, None, None,   0          ['stage3_unit1_relu1[0][0]']
#  g2D)                           128)
#
#  stage3_unit1_conv1 (Conv2D)    (None, None, None,   294912      ['zero_padding2d_186[0][0]']
#                                 256)
#
#  stage3_unit1_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit1_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit1_relu2 (Activation  (None, None, None,   0          ['stage3_unit1_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_187 (ZeroPaddin  (None, None, None,   0          ['stage3_unit1_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit1_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_187[0][0]']
#                                 256)
#
#  stage3_unit1_sc (Conv2D)       (None, None, None,   32768       ['stage3_unit1_relu1[0][0]']
#                                 256)
#
#  add_87 (Add)                   (None, None, None,   0           ['stage3_unit1_conv2[0][0]',
#                                 256)                              'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, None, None,   1024       ['add_87[0][0]']
#  zation)                        256)
#
#  stage3_unit2_relu1 (Activation  (None, None, None,   0          ['stage3_unit2_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_188 (ZeroPaddin  (None, None, None,   0          ['stage3_unit2_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit2_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_188[0][0]']
#                                 256)
#
#  stage3_unit2_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit2_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit2_relu2 (Activation  (None, None, None,   0          ['stage3_unit2_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_189 (ZeroPaddin  (None, None, None,   0          ['stage3_unit2_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit2_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_189[0][0]']
#                                 256)
#
#  add_88 (Add)                   (None, None, None,   0           ['stage3_unit2_conv2[0][0]',
#                                 256)                              'add_87[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, None, None,   1024       ['add_88[0][0]']
#  zation)                        256)
#
#  stage3_unit3_relu1 (Activation  (None, None, None,   0          ['stage3_unit3_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_190 (ZeroPaddin  (None, None, None,   0          ['stage3_unit3_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit3_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_190[0][0]']
#                                 256)
#
#  stage3_unit3_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit3_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit3_relu2 (Activation  (None, None, None,   0          ['stage3_unit3_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_191 (ZeroPaddin  (None, None, None,   0          ['stage3_unit3_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit3_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_191[0][0]']
#                                 256)
#
#  add_89 (Add)                   (None, None, None,   0           ['stage3_unit3_conv2[0][0]',
#                                 256)                              'add_88[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, None, None,   1024       ['add_89[0][0]']
#  zation)                        256)
#
#  stage3_unit4_relu1 (Activation  (None, None, None,   0          ['stage3_unit4_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_192 (ZeroPaddin  (None, None, None,   0          ['stage3_unit4_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit4_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_192[0][0]']
#                                 256)
#
#  stage3_unit4_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit4_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit4_relu2 (Activation  (None, None, None,   0          ['stage3_unit4_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_193 (ZeroPaddin  (None, None, None,   0          ['stage3_unit4_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit4_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_193[0][0]']
#                                 256)
#
#  add_90 (Add)                   (None, None, None,   0           ['stage3_unit4_conv2[0][0]',
#                                 256)                              'add_89[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, None, None,   1024       ['add_90[0][0]']
#  zation)                        256)
#
#  stage3_unit5_relu1 (Activation  (None, None, None,   0          ['stage3_unit5_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_194 (ZeroPaddin  (None, None, None,   0          ['stage3_unit5_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit5_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_194[0][0]']
#                                 256)
#
#  stage3_unit5_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit5_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit5_relu2 (Activation  (None, None, None,   0          ['stage3_unit5_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_195 (ZeroPaddin  (None, None, None,   0          ['stage3_unit5_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit5_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_195[0][0]']
#                                 256)
#
#  add_91 (Add)                   (None, None, None,   0           ['stage3_unit5_conv2[0][0]',
#                                 256)                              'add_90[0][0]']
#
#  stage3_unit6_bn1 (BatchNormali  (None, None, None,   1024       ['add_91[0][0]']
#  zation)                        256)
#
#  stage3_unit6_relu1 (Activation  (None, None, None,   0          ['stage3_unit6_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_196 (ZeroPaddin  (None, None, None,   0          ['stage3_unit6_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit6_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_196[0][0]']
#                                 256)
#
#  stage3_unit6_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit6_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit6_relu2 (Activation  (None, None, None,   0          ['stage3_unit6_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_197 (ZeroPaddin  (None, None, None,   0          ['stage3_unit6_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit6_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_197[0][0]']
#                                 256)
#
#  add_92 (Add)                   (None, None, None,   0           ['stage3_unit6_conv2[0][0]',
#                                 256)                              'add_91[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, None, None,   1024       ['add_92[0][0]']
#  zation)                        256)
#
#  stage4_unit1_relu1 (Activation  (None, None, None,   0          ['stage4_unit1_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_198 (ZeroPaddin  (None, None, None,   0          ['stage4_unit1_relu1[0][0]']
#  g2D)                           256)
#
#  stage4_unit1_conv1 (Conv2D)    (None, None, None,   1179648     ['zero_padding2d_198[0][0]']
#                                 512)
#
#  stage4_unit1_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit1_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit1_relu2 (Activation  (None, None, None,   0          ['stage4_unit1_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_199 (ZeroPaddin  (None, None, None,   0          ['stage4_unit1_relu2[0][0]']
#  g2D)                           512)
#
#  stage4_unit1_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_199[0][0]']
#                                 512)
#
#  stage4_unit1_sc (Conv2D)       (None, None, None,   131072      ['stage4_unit1_relu1[0][0]']
#                                 512)
#
#  add_93 (Add)                   (None, None, None,   0           ['stage4_unit1_conv2[0][0]',
#                                 512)                              'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, None, None,   2048       ['add_93[0][0]']
#  zation)                        512)
#
#  stage4_unit2_relu1 (Activation  (None, None, None,   0          ['stage4_unit2_bn1[0][0]']
#  )                              512)
#
#  zero_padding2d_200 (ZeroPaddin  (None, None, None,   0          ['stage4_unit2_relu1[0][0]']
#  g2D)                           512)
#
#  stage4_unit2_conv1 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_200[0][0]']
#                                 512)
#
#  stage4_unit2_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit2_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit2_relu2 (Activation  (None, None, None,   0          ['stage4_unit2_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_201 (ZeroPaddin  (None, None, None,   0          ['stage4_unit2_relu2[0][0]']
#  g2D)                           512)
#
#  stage4_unit2_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_201[0][0]']
#                                 512)
#
#  add_94 (Add)                   (None, None, None,   0           ['stage4_unit2_conv2[0][0]',
#                                 512)                              'add_93[0][0]']
#
#  stage4_unit3_bn1 (BatchNormali  (None, None, None,   2048       ['add_94[0][0]']
#  zation)                        512)
#
#  stage4_unit3_relu1 (Activation  (None, None, None,   0          ['stage4_unit3_bn1[0][0]']
#  )                              512)
#
#  zero_padding2d_202 (ZeroPaddin  (None, None, None,   0          ['stage4_unit3_relu1[0][0]']
#  g2D)                           512)
#
#  stage4_unit3_conv1 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_202[0][0]']
#                                 512)
#
#  stage4_unit3_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit3_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit3_relu2 (Activation  (None, None, None,   0          ['stage4_unit3_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_203 (ZeroPaddin  (None, None, None,   0          ['stage4_unit3_relu2[0][0]']
#  g2D)                           512)
#
#  stage4_unit3_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_203[0][0]']
#                                 512)
#
#  add_95 (Add)                   (None, None, None,   0           ['stage4_unit3_conv2[0][0]',
#                                 512)                              'add_94[0][0]']
#
#  bn1 (BatchNormalization)       (None, None, None,   2048        ['add_95[0][0]']
#                                 512)
#
#  relu1 (Activation)             (None, None, None,   0           ['bn1[0][0]']
#                                 512)
#
#  decoder_stage0_upsampling (UpS  (None, None, None,   0          ['relu1[0][0]']
#  ampling2D)                     512)
#
#  decoder_stage0_concat (Concate  (None, None, None,   0          ['decoder_stage0_upsampling[0][0]
#  nate)                          768)                             ',
#                                                                   'stage4_unit1_relu1[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, None, None,   1769472     ['decoder_stage0_concat[0][0]']
#                                 256)
#
#  decoder_stage0a_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0a_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0a_relu (Activati  (None, None, None,   0          ['decoder_stage0a_bn[0][0]']
#  on)                            256)
#
#  decoder_stage0b_conv (Conv2D)  (None, None, None,   589824      ['decoder_stage0a_relu[0][0]']
#                                 256)
#
#  decoder_stage0b_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0b_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0b_relu (Activati  (None, None, None,   0          ['decoder_stage0b_bn[0][0]']
#  on)                            256)
#
#  decoder_stage1_upsampling (UpS  (None, None, None,   0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)                     256)
#
#  decoder_stage1_concat (Concate  (None, None, None,   0          ['decoder_stage1_upsampling[0][0]
#  nate)                          384)                             ',
#                                                                   'stage3_unit1_relu1[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, None, None,   442368      ['decoder_stage1_concat[0][0]']
#                                 128)
#
#  decoder_stage1a_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1a_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1a_relu (Activati  (None, None, None,   0          ['decoder_stage1a_bn[0][0]']
#  on)                            128)
#
#  decoder_stage1b_conv (Conv2D)  (None, None, None,   147456      ['decoder_stage1a_relu[0][0]']
#                                 128)
#
#  decoder_stage1b_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1b_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1b_relu (Activati  (None, None, None,   0          ['decoder_stage1b_bn[0][0]']
#  on)                            128)
#
#  decoder_stage2_upsampling (UpS  (None, None, None,   0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)                     128)
#
#  decoder_stage2_concat (Concate  (None, None, None,   0          ['decoder_stage2_upsampling[0][0]
#  nate)                          192)                             ',
#                                                                   'stage2_unit1_relu1[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, None, None,   110592      ['decoder_stage2_concat[0][0]']
#                                 64)
#
#  decoder_stage2a_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2a_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2a_relu (Activati  (None, None, None,   0          ['decoder_stage2a_bn[0][0]']
#  on)                            64)
#
#  decoder_stage2b_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage2a_relu[0][0]']
#                                 64)
#
#  decoder_stage2b_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2b_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2b_relu (Activati  (None, None, None,   0          ['decoder_stage2b_bn[0][0]']
#  on)                            64)
#
#  decoder_stage3_upsampling (UpS  (None, None, None,   0          ['decoder_stage2b_relu[0][0]']
#  ampling2D)                     64)
#
#  decoder_stage3_concat (Concate  (None, None, None,   0          ['decoder_stage3_upsampling[0][0]
#  nate)                          128)                             ',
#                                                                   'relu0[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage3_concat[0][0]']
#                                 32)
#
#  decoder_stage3a_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3a_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3a_relu (Activati  (None, None, None,   0          ['decoder_stage3a_bn[0][0]']
#  on)                            32)
#
#  decoder_stage3b_conv (Conv2D)  (None, None, None,   9216        ['decoder_stage3a_relu[0][0]']
#                                 32)
#
#  decoder_stage3b_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3b_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3b_relu (Activati  (None, None, None,   0          ['decoder_stage3b_bn[0][0]']
#  on)                            32)
#
#  decoder_stage4_upsampling (UpS  (None, None, None,   0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     32)
#
#  decoder_stage4a_conv (Conv2D)  (None, None, None,   4608        ['decoder_stage4_upsampling[0][0]
#                                 16)                              ']
#
#  decoder_stage4a_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4a_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4a_relu (Activati  (None, None, None,   0          ['decoder_stage4a_bn[0][0]']
#  on)                            16)
#
#  decoder_stage4b_conv (Conv2D)  (None, None, None,   2304        ['decoder_stage4a_relu[0][0]']
#                                 16)
#
#  decoder_stage4b_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4b_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4b_relu (Activati  (None, None, None,   0          ['decoder_stage4b_bn[0][0]']
#  on)                            16)
#
#  final_conv (Conv2D)            (None, None, None,   870         ['decoder_stage4b_relu[0][0]']
#                                 6)
#
#  softmax (Activation)           (None, None, None,   0           ['final_conv[0][0]']
#                                 6)
#
# ==================================================================================================
# Total params: 24,456,879
# Trainable params: 24,439,529
# Non-trainable params: 17,350
# __________________________________________________________________________________________________

# %%
history_2=model_2.fit(
          train_img_gen,
          steps_per_epoch=steps_per_epoch,
          epochs=100,
          verbose=1,
# Epoch 94/100
# 49/49 [==============================] - 16s 326ms/step - loss: 0.0481 - accuracy: 0.8953 - iou_score: 0.5774 - f1-score: 0.6810 - val_loss: 0.0684 - val_accuracy: 0.8644 - val_iou_score: 0.5148 - val_f1-score: 0.6276
# Epoch 95/100
# 49/49 [==============================] - 16s 328ms/step - loss: 0.0443 - accuracy: 0.9032 - iou_score: 0.5863 - f1-score: 0.6862 - val_loss: 0.0611 - val_accuracy: 0.8773 - val_iou_score: 0.5490 - val_f1-score: 0.6548
# Epoch 96/100
# 49/49 [==============================] - 27s 556ms/step - loss: 0.0457 - accuracy: 0.8989 - iou_score: 0.5863 - f1-score: 0.6862 - val_loss: 0.0577 - val_accuracy: 0.8802 - val_iou_score: 0.5506 - val_f1-score: 0.6575
# Epoch 97/100
# 49/49 [==============================] - 37s 772ms/step - loss: 0.0437 - accuracy: 0.9052 - iou_score: 0.5879 - f1-score: 0.6881 - val_loss: 0.0681 - val_accuracy: 0.8733 - val_iou_score: 0.5287 - val_f1-score: 0.6381
# Epoch 98/100
# 49/49 [==============================] - 29s 602ms/step - loss: 0.0434 - accuracy: 0.9038 - iou_score: 0.5964 - f1-score: 0.6950 - val_loss: 0.0593 - val_accuracy: 0.8862 - val_iou_score: 0.5609 - val_f1-score: 0.6652
# Epoch 99/100
# 49/49 [==============================] - 15s 308ms/step - loss: 0.0433 - accuracy: 0.9046 - iou_score: 0.5941 - f1-score: 0.6933 - val_loss: 0.0580 - val_accuracy: 0.8849 - val_iou_score: 0.5699 - val_f1-score: 0.6740
# Epoch 100/100
# 49/49 [==============================] - 15s 308ms/step - loss: 0.0421 - accuracy: 0.9067 - iou_score: 0.6003 - f1-score: 0.6995 - val_loss: 0.0591 - val_accuracy: 0.8841 - val_iou_score: 0.5656 - val_f1-score: 0.6682

# %% [markdown]
# ## Модель 3
# Функция потерь **Categorical Focal Dice Loss**

# %%
metrics = ['accuracy', sm.metrics.iou_score, sm.metrics.FScore()]
model_3 = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation='softmax')

model_3.compile(optimizer='adam', loss=sm.losses.categorical_focal_dice_loss, metrics=metrics)
model_3.summary()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, None, None,  0           []
#                                  3)]
#
#  bn_data (BatchNormalization)   (None, None, None,   9           ['data[0][0]']
#                                 3)
#
#  zero_padding2d_204 (ZeroPaddin  (None, None, None,   0          ['bn_data[0][0]']
#  g2D)                           3)
#
#  conv0 (Conv2D)                 (None, None, None,   9408        ['zero_padding2d_204[0][0]']
#                                 64)
#
#  bn0 (BatchNormalization)       (None, None, None,   256         ['conv0[0][0]']
#                                 64)
#
#  relu0 (Activation)             (None, None, None,   0           ['bn0[0][0]']
#                                 64)
#
#  zero_padding2d_205 (ZeroPaddin  (None, None, None,   0          ['relu0[0][0]']
#  g2D)                           64)
#
#  pooling0 (MaxPooling2D)        (None, None, None,   0           ['zero_padding2d_205[0][0]']
#                                 64)
#
#  stage1_unit1_bn1 (BatchNormali  (None, None, None,   256        ['pooling0[0][0]']
#  zation)                        64)
#
#  stage1_unit1_relu1 (Activation  (None, None, None,   0          ['stage1_unit1_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_206 (ZeroPaddin  (None, None, None,   0          ['stage1_unit1_relu1[0][0]']
#  g2D)                           64)
#
#  stage1_unit1_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_206[0][0]']
#                                 64)
#
#  stage1_unit1_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit1_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit1_relu2 (Activation  (None, None, None,   0          ['stage1_unit1_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_207 (ZeroPaddin  (None, None, None,   0          ['stage1_unit1_relu2[0][0]']
#  g2D)                           64)
#
#  stage1_unit1_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_207[0][0]']
#                                 64)
#
#  stage1_unit1_sc (Conv2D)       (None, None, None,   4096        ['stage1_unit1_relu1[0][0]']
#                                 64)
#
#  add_96 (Add)                   (None, None, None,   0           ['stage1_unit1_conv2[0][0]',
#                                 64)                               'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, None, None,   256        ['add_96[0][0]']
#  zation)                        64)
#
#  stage1_unit2_relu1 (Activation  (None, None, None,   0          ['stage1_unit2_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_208 (ZeroPaddin  (None, None, None,   0          ['stage1_unit2_relu1[0][0]']
#  g2D)                           64)
#
#  stage1_unit2_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_208[0][0]']
#                                 64)
#
#  stage1_unit2_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit2_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit2_relu2 (Activation  (None, None, None,   0          ['stage1_unit2_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_209 (ZeroPaddin  (None, None, None,   0          ['stage1_unit2_relu2[0][0]']
#  g2D)                           64)
#
#  stage1_unit2_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_209[0][0]']
#                                 64)
#
#  add_97 (Add)                   (None, None, None,   0           ['stage1_unit2_conv2[0][0]',
#                                 64)                               'add_96[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, None, None,   256        ['add_97[0][0]']
#  zation)                        64)
#
#  stage1_unit3_relu1 (Activation  (None, None, None,   0          ['stage1_unit3_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_210 (ZeroPaddin  (None, None, None,   0          ['stage1_unit3_relu1[0][0]']
#  g2D)                           64)
#
#  stage1_unit3_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_210[0][0]']
#                                 64)
#
#  stage1_unit3_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit3_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit3_relu2 (Activation  (None, None, None,   0          ['stage1_unit3_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_211 (ZeroPaddin  (None, None, None,   0          ['stage1_unit3_relu2[0][0]']
#  g2D)                           64)
#
#  stage1_unit3_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_211[0][0]']
#                                 64)
#
#  add_98 (Add)                   (None, None, None,   0           ['stage1_unit3_conv2[0][0]',
#                                 64)                               'add_97[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, None, None,   256        ['add_98[0][0]']
#  zation)                        64)
#
#  stage2_unit1_relu1 (Activation  (None, None, None,   0          ['stage2_unit1_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_212 (ZeroPaddin  (None, None, None,   0          ['stage2_unit1_relu1[0][0]']
#  g2D)                           64)
#
#  stage2_unit1_conv1 (Conv2D)    (None, None, None,   73728       ['zero_padding2d_212[0][0]']
#                                 128)
#
#  stage2_unit1_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit1_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit1_relu2 (Activation  (None, None, None,   0          ['stage2_unit1_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_213 (ZeroPaddin  (None, None, None,   0          ['stage2_unit1_relu2[0][0]']
#  g2D)                           128)
#
#  stage2_unit1_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_213[0][0]']
#                                 128)
#
#  stage2_unit1_sc (Conv2D)       (None, None, None,   8192        ['stage2_unit1_relu1[0][0]']
#                                 128)
#
#  add_99 (Add)                   (None, None, None,   0           ['stage2_unit1_conv2[0][0]',
#                                 128)                              'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, None, None,   512        ['add_99[0][0]']
#  zation)                        128)
#
#  stage2_unit2_relu1 (Activation  (None, None, None,   0          ['stage2_unit2_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_214 (ZeroPaddin  (None, None, None,   0          ['stage2_unit2_relu1[0][0]']
#  g2D)                           128)
#
#  stage2_unit2_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_214[0][0]']
#                                 128)
#
#  stage2_unit2_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit2_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit2_relu2 (Activation  (None, None, None,   0          ['stage2_unit2_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_215 (ZeroPaddin  (None, None, None,   0          ['stage2_unit2_relu2[0][0]']
#  g2D)                           128)
#
#  stage2_unit2_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_215[0][0]']
#                                 128)
#
#  add_100 (Add)                  (None, None, None,   0           ['stage2_unit2_conv2[0][0]',
#                                 128)                              'add_99[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, None, None,   512        ['add_100[0][0]']
#  zation)                        128)
#
#  stage2_unit3_relu1 (Activation  (None, None, None,   0          ['stage2_unit3_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_216 (ZeroPaddin  (None, None, None,   0          ['stage2_unit3_relu1[0][0]']
#  g2D)                           128)
#
#  stage2_unit3_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_216[0][0]']
#                                 128)
#
#  stage2_unit3_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit3_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit3_relu2 (Activation  (None, None, None,   0          ['stage2_unit3_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_217 (ZeroPaddin  (None, None, None,   0          ['stage2_unit3_relu2[0][0]']
#  g2D)                           128)
#
#  stage2_unit3_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_217[0][0]']
#                                 128)
#
#  add_101 (Add)                  (None, None, None,   0           ['stage2_unit3_conv2[0][0]',
#                                 128)                              'add_100[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, None, None,   512        ['add_101[0][0]']
#  zation)                        128)
#
#  stage2_unit4_relu1 (Activation  (None, None, None,   0          ['stage2_unit4_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_218 (ZeroPaddin  (None, None, None,   0          ['stage2_unit4_relu1[0][0]']
#  g2D)                           128)
#
#  stage2_unit4_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_218[0][0]']
#                                 128)
#
#  stage2_unit4_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit4_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit4_relu2 (Activation  (None, None, None,   0          ['stage2_unit4_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_219 (ZeroPaddin  (None, None, None,   0          ['stage2_unit4_relu2[0][0]']
#  g2D)                           128)
#
#  stage2_unit4_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_219[0][0]']
#                                 128)
#
#  add_102 (Add)                  (None, None, None,   0           ['stage2_unit4_conv2[0][0]',
#                                 128)                              'add_101[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, None, None,   512        ['add_102[0][0]']
#  zation)                        128)
#
#  stage3_unit1_relu1 (Activation  (None, None, None,   0          ['stage3_unit1_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_220 (ZeroPaddin  (None, None, None,   0          ['stage3_unit1_relu1[0][0]']
#  g2D)                           128)
#
#  stage3_unit1_conv1 (Conv2D)    (None, None, None,   294912      ['zero_padding2d_220[0][0]']
#                                 256)
#
#  stage3_unit1_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit1_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit1_relu2 (Activation  (None, None, None,   0          ['stage3_unit1_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_221 (ZeroPaddin  (None, None, None,   0          ['stage3_unit1_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit1_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_221[0][0]']
#                                 256)
#
#  stage3_unit1_sc (Conv2D)       (None, None, None,   32768       ['stage3_unit1_relu1[0][0]']
#                                 256)
#
#  add_103 (Add)                  (None, None, None,   0           ['stage3_unit1_conv2[0][0]',
#                                 256)                              'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, None, None,   1024       ['add_103[0][0]']
#  zation)                        256)
#
#  stage3_unit2_relu1 (Activation  (None, None, None,   0          ['stage3_unit2_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_222 (ZeroPaddin  (None, None, None,   0          ['stage3_unit2_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit2_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_222[0][0]']
#                                 256)
#
#  stage3_unit2_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit2_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit2_relu2 (Activation  (None, None, None,   0          ['stage3_unit2_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_223 (ZeroPaddin  (None, None, None,   0          ['stage3_unit2_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit2_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_223[0][0]']
#                                 256)
#
#  add_104 (Add)                  (None, None, None,   0           ['stage3_unit2_conv2[0][0]',
#                                 256)                              'add_103[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, None, None,   1024       ['add_104[0][0]']
#  zation)                        256)
#
#  stage3_unit3_relu1 (Activation  (None, None, None,   0          ['stage3_unit3_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_224 (ZeroPaddin  (None, None, None,   0          ['stage3_unit3_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit3_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_224[0][0]']
#                                 256)
#
#  stage3_unit3_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit3_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit3_relu2 (Activation  (None, None, None,   0          ['stage3_unit3_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_225 (ZeroPaddin  (None, None, None,   0          ['stage3_unit3_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit3_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_225[0][0]']
#                                 256)
#
#  add_105 (Add)                  (None, None, None,   0           ['stage3_unit3_conv2[0][0]',
#                                 256)                              'add_104[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, None, None,   1024       ['add_105[0][0]']
#  zation)                        256)
#
#  stage3_unit4_relu1 (Activation  (None, None, None,   0          ['stage3_unit4_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_226 (ZeroPaddin  (None, None, None,   0          ['stage3_unit4_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit4_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_226[0][0]']
#                                 256)
#
#  stage3_unit4_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit4_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit4_relu2 (Activation  (None, None, None,   0          ['stage3_unit4_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_227 (ZeroPaddin  (None, None, None,   0          ['stage3_unit4_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit4_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_227[0][0]']
#                                 256)
#
#  add_106 (Add)                  (None, None, None,   0           ['stage3_unit4_conv2[0][0]',
#                                 256)                              'add_105[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, None, None,   1024       ['add_106[0][0]']
#  zation)                        256)
#
#  stage3_unit5_relu1 (Activation  (None, None, None,   0          ['stage3_unit5_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_228 (ZeroPaddin  (None, None, None,   0          ['stage3_unit5_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit5_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_228[0][0]']
#                                 256)
#
#  stage3_unit5_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit5_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit5_relu2 (Activation  (None, None, None,   0          ['stage3_unit5_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_229 (ZeroPaddin  (None, None, None,   0          ['stage3_unit5_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit5_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_229[0][0]']
#                                 256)
#
#  add_107 (Add)                  (None, None, None,   0           ['stage3_unit5_conv2[0][0]',
#                                 256)                              'add_106[0][0]']
#
#  stage3_unit6_bn1 (BatchNormali  (None, None, None,   1024       ['add_107[0][0]']
#  zation)                        256)
#
#  stage3_unit6_relu1 (Activation  (None, None, None,   0          ['stage3_unit6_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_230 (ZeroPaddin  (None, None, None,   0          ['stage3_unit6_relu1[0][0]']
#  g2D)                           256)
#
#  stage3_unit6_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_230[0][0]']
#                                 256)
#
#  stage3_unit6_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit6_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit6_relu2 (Activation  (None, None, None,   0          ['stage3_unit6_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_231 (ZeroPaddin  (None, None, None,   0          ['stage3_unit6_relu2[0][0]']
#  g2D)                           256)
#
#  stage3_unit6_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_231[0][0]']
#                                 256)
#
#  add_108 (Add)                  (None, None, None,   0           ['stage3_unit6_conv2[0][0]',
#                                 256)                              'add_107[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, None, None,   1024       ['add_108[0][0]']
#  zation)                        256)
#
#  stage4_unit1_relu1 (Activation  (None, None, None,   0          ['stage4_unit1_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_232 (ZeroPaddin  (None, None, None,   0          ['stage4_unit1_relu1[0][0]']
#  g2D)                           256)
#
#  stage4_unit1_conv1 (Conv2D)    (None, None, None,   1179648     ['zero_padding2d_232[0][0]']
#                                 512)
#
#  stage4_unit1_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit1_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit1_relu2 (Activation  (None, None, None,   0          ['stage4_unit1_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_233 (ZeroPaddin  (None, None, None,   0          ['stage4_unit1_relu2[0][0]']
#  g2D)                           512)
#
#  stage4_unit1_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_233[0][0]']
#                                 512)
#
#  stage4_unit1_sc (Conv2D)       (None, None, None,   131072      ['stage4_unit1_relu1[0][0]']
#                                 512)
#
#  add_109 (Add)                  (None, None, None,   0           ['stage4_unit1_conv2[0][0]',
#                                 512)                              'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, None, None,   2048       ['add_109[0][0]']
#  zation)                        512)
#
#  stage4_unit2_relu1 (Activation  (None, None, None,   0          ['stage4_unit2_bn1[0][0]']
#  )                              512)
#
#  zero_padding2d_234 (ZeroPaddin  (None, None, None,   0          ['stage4_unit2_relu1[0][0]']
#  g2D)                           512)
#
#  stage4_unit2_conv1 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_234[0][0]']
#                                 512)
#
#  stage4_unit2_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit2_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit2_relu2 (Activation  (None, None, None,   0          ['stage4_unit2_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_235 (ZeroPaddin  (None, None, None,   0          ['stage4_unit2_relu2[0][0]']
#  g2D)                           512)
#
#  stage4_unit2_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_235[0][0]']
#                                 512)
#
#  add_110 (Add)                  (None, None, None,   0           ['stage4_unit2_conv2[0][0]',
#                                 512)                              'add_109[0][0]']
#
#  stage4_unit3_bn1 (BatchNormali  (None, None, None,   2048       ['add_110[0][0]']
#  zation)                        512)
#
#  stage4_unit3_relu1 (Activation  (None, None, None,   0          ['stage4_unit3_bn1[0][0]']
#  )                              512)
#
#  zero_padding2d_236 (ZeroPaddin  (None, None, None,   0          ['stage4_unit3_relu1[0][0]']
#  g2D)                           512)
#
#  stage4_unit3_conv1 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_236[0][0]']
#                                 512)
#
#  stage4_unit3_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit3_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit3_relu2 (Activation  (None, None, None,   0          ['stage4_unit3_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_237 (ZeroPaddin  (None, None, None,   0          ['stage4_unit3_relu2[0][0]']
#  g2D)                           512)
#
#  stage4_unit3_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_237[0][0]']
#                                 512)
#
#  add_111 (Add)                  (None, None, None,   0           ['stage4_unit3_conv2[0][0]',
#                                 512)                              'add_110[0][0]']
#
#  bn1 (BatchNormalization)       (None, None, None,   2048        ['add_111[0][0]']
#                                 512)
#
#  relu1 (Activation)             (None, None, None,   0           ['bn1[0][0]']
#                                 512)
#
#  decoder_stage0_upsampling (UpS  (None, None, None,   0          ['relu1[0][0]']
#  ampling2D)                     512)
#
#  decoder_stage0_concat (Concate  (None, None, None,   0          ['decoder_stage0_upsampling[0][0]
#  nate)                          768)                             ',
#                                                                   'stage4_unit1_relu1[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, None, None,   1769472     ['decoder_stage0_concat[0][0]']
#                                 256)
#
#  decoder_stage0a_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0a_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0a_relu (Activati  (None, None, None,   0          ['decoder_stage0a_bn[0][0]']
#  on)                            256)
#
#  decoder_stage0b_conv (Conv2D)  (None, None, None,   589824      ['decoder_stage0a_relu[0][0]']
#                                 256)
#
#  decoder_stage0b_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0b_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0b_relu (Activati  (None, None, None,   0          ['decoder_stage0b_bn[0][0]']
#  on)                            256)
#
#  decoder_stage1_upsampling (UpS  (None, None, None,   0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)                     256)
#
#  decoder_stage1_concat (Concate  (None, None, None,   0          ['decoder_stage1_upsampling[0][0]
#  nate)                          384)                             ',
#                                                                   'stage3_unit1_relu1[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, None, None,   442368      ['decoder_stage1_concat[0][0]']
#                                 128)
#
#  decoder_stage1a_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1a_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1a_relu (Activati  (None, None, None,   0          ['decoder_stage1a_bn[0][0]']
#  on)                            128)
#
#  decoder_stage1b_conv (Conv2D)  (None, None, None,   147456      ['decoder_stage1a_relu[0][0]']
#                                 128)
#
#  decoder_stage1b_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1b_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1b_relu (Activati  (None, None, None,   0          ['decoder_stage1b_bn[0][0]']
#  on)                            128)
#
#  decoder_stage2_upsampling (UpS  (None, None, None,   0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)                     128)
#
#  decoder_stage2_concat (Concate  (None, None, None,   0          ['decoder_stage2_upsampling[0][0]
#  nate)                          192)                             ',
#                                                                   'stage2_unit1_relu1[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, None, None,   110592      ['decoder_stage2_concat[0][0]']
#                                 64)
#
#  decoder_stage2a_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2a_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2a_relu (Activati  (None, None, None,   0          ['decoder_stage2a_bn[0][0]']
#  on)                            64)
#
#  decoder_stage2b_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage2a_relu[0][0]']
#                                 64)
#
#  decoder_stage2b_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2b_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2b_relu (Activati  (None, None, None,   0          ['decoder_stage2b_bn[0][0]']
#  on)                            64)
#
#  decoder_stage3_upsampling (UpS  (None, None, None,   0          ['decoder_stage2b_relu[0][0]']
#  ampling2D)                     64)
#
#  decoder_stage3_concat (Concate  (None, None, None,   0          ['decoder_stage3_upsampling[0][0]
#  nate)                          128)                             ',
#                                                                   'relu0[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage3_concat[0][0]']
#                                 32)
#
#  decoder_stage3a_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3a_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3a_relu (Activati  (None, None, None,   0          ['decoder_stage3a_bn[0][0]']
#  on)                            32)
#
#  decoder_stage3b_conv (Conv2D)  (None, None, None,   9216        ['decoder_stage3a_relu[0][0]']
#                                 32)
#
#  decoder_stage3b_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3b_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3b_relu (Activati  (None, None, None,   0          ['decoder_stage3b_bn[0][0]']
#  on)                            32)
#
#  decoder_stage4_upsampling (UpS  (None, None, None,   0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     32)
#
#  decoder_stage4a_conv (Conv2D)  (None, None, None,   4608        ['decoder_stage4_upsampling[0][0]
#                                 16)                              ']
#
#  decoder_stage4a_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4a_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4a_relu (Activati  (None, None, None,   0          ['decoder_stage4a_bn[0][0]']
#  on)                            16)
#
#  decoder_stage4b_conv (Conv2D)  (None, None, None,   2304        ['decoder_stage4a_relu[0][0]']
#                                 16)
#
#  decoder_stage4b_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4b_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4b_relu (Activati  (None, None, None,   0          ['decoder_stage4b_bn[0][0]']
#  on)                            16)
#
#  final_conv (Conv2D)            (None, None, None,   870         ['decoder_stage4b_relu[0][0]']
#                                 6)
#
#  softmax (Activation)           (None, None, None,   0           ['final_conv[0][0]']
#                                 6)
#
# ==================================================================================================
# Total params: 24,456,879
# Trainable params: 24,439,529
# Non-trainable params: 17,350
# __________________________________________________________________________________________________

# %%
history_3=model_3.fit(
          train_img_gen,
          steps_per_epoch=steps_per_epoch,
          epochs=100,
          verbose=1,
          validation_steps=val_steps_per_epoch,
          validation_data=val_img_gen)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 19s 316ms/step - loss: 0.5820 - accuracy: 0.7041 - iou_score: 0.3330 - f1-score: 0.4488 - val_loss: 1.5348 - val_accuracy: 0.1282 - val_iou_score: 0.0256 - val_f1-score: 0.0467
# Epoch 2/100
# 49/49 [==============================] - 15s 298ms/step - loss: 0.4400 - accuracy: 0.7965 - iou_score: 0.4770 - f1-score: 0.5928 - val_loss: 1.0353 - val_accuracy: 0.3948 - val_iou_score: 0.0890 - val_f1-score: 0.1348
# Epoch 3/100
# 49/49 [==============================] - 15s 301ms/step - loss: 0.4248 - accuracy: 0.8085 - iou_score: 0.4945 - f1-score: 0.6082 - val_loss: 1.0515 - val_accuracy: 0.5553 - val_iou_score: 0.0967 - val_f1-score: 0.1279
# Epoch 4/100
# 49/49 [==============================] - 15s 312ms/step - loss: 0.2812 - accuracy: 0.8726 - iou_score: 0.6360 - f1-score: 0.7415 - val_loss: 0.3539 - val_accuracy: 0.8647 - val_iou_score: 0.5719 - val_f1-score: 0.6707
# Epoch 98/100
# 49/49 [==============================] - 15s 310ms/step - loss: 0.2736 - accuracy: 0.8756 - iou_score: 0.6435 - f1-score: 0.7480 - val_loss: 0.3434 - val_accuracy: 0.8724 - val_iou_score: 0.5803 - val_f1-score: 0.6786
# Epoch 99/100
# 49/49 [==============================] - 15s 315ms/step - loss: 0.2735 - accuracy: 0.8790 - iou_score: 0.6429 - f1-score: 0.7459 - val_loss: 0.3343 - val_accuracy: 0.8726 - val_iou_score: 0.5887 - val_f1-score: 0.6881
# Epoch 100/100
# 49/49 [==============================] - 16s 319ms/step - loss: 0.2717 - accuracy: 0.8764 - iou_score: 0.6432 - f1-score: 0.7468 - val_loss: 0.3305 - val_accuracy: 0.8706 - val_iou_score: 0.5883 - val_f1-score: 0.6933

# %%
model_1.save('.\models\Model1.h5')
model_2.save('.\models\Model2.h5')
model_3.save('.\models\Model3.h5')

# %% [markdown]
# # Этап 4. Визуализация процесса обучения. Оценка точности

# %%
def display_training(history, name):
    fig, axs = plt.subplots(4, 1, sharex=True)
    
    fig.set_figwidth(15)
    fig.set_figheight(15)
    fig.suptitle(name)
    plt.xlabel('Epochs', fontsize=10)
    
    axs[0].set_title("Training and validation loss")
    axs[0].plot(history.history['loss'])
    axs[0].plot(history.history['val_loss'])
    axs[0].set_ylabel('Loss')
    axs[0].legend(['Training loss', 'Validation loss'], loc="upper right")

    axs[1].set_title("Training and validation accuracy")
    axs[1].plot(history.history['accuracy'])
    axs[1].plot(history.history['val_accuracy'])
    axs[1].set_ylabel('Accuracy')
    axs[1].legend(['Training accuracy', 'Validation accuracy'], loc="lower right")

    axs[2].set_title("Training and validation IOU score")
    axs[2].plot(history.history['iou_score'])
    axs[2].plot(history.history['val_iou_score'])
    axs[2].set_ylabel('IOU score')
    axs[2].legend(['Training IOU score', 'Validation IOU score'], loc="lower right")

    axs[3].set_title("Training and validation F1 score")
    axs[3].plot(history.history['f1-score'])
    axs[3].plot(history.history['val_f1-score'])
    axs[3].set_ylabel('F1 score')
    _  = axs[3].legend(['Training F1 score', 'Validation F1 score'], loc="lower right")

    fig.subplots_adjust(bottom=0.1, top=0.95)

# %%
# Визуализация обучения модели 1
display_training(history_1, 'Model 1: Сategorical Focal Jaccard Loss')

# %%
# Визуализация обучения модели 2
display_training(history_2, 'Model 2: Categorical CE Loss')

# %%
# Визуализация обучения модели 3
display_training(history_3, 'Model 3: Categorical Focal Dice Loss')

# %%
# Оценка моделей
from keras.models import load_model
from keras.metrics import MeanIoU 

def print_mean_iou(num_classes, test_pred_batch_argmax, test_mask_batch_argmax):
    IOU_keras = MeanIoU(num_classes=num_classes)  
    IOU_keras.update_state(test_pred_batch_argmax, test_mask_batch_argmax)
    print("Mean IoU =", IOU_keras.result().numpy()) 

model_1 = load_model('.\models\Model1.h5', compile=False)
model_2 = load_model('.\models\Model2.h5', compile=False)
model_3 = load_model('.\models\Model3.h5', compile=False)

test_image_batch, test_mask_batch = val_img_gen.__next__()
test_mask_batch_argmax = np.argmax(test_mask_batch, axis=3) 

test_pred_batch_model_1 = model_1.predict(test_image_batch)
test_pred_batch_model_2 = model_2.predict(test_image_batch)
test_pred_batch_model_3 = model_3.predict(test_image_batch)

test_pred_batch_model_1_argmax = np.argmax(test_pred_batch_model_1, axis=3)
test_pred_batch_model_2_argmax = np.argmax(test_pred_batch_model_2, axis=3)
test_pred_batch_model_3_argmax = np.argmax(test_pred_batch_model_3, axis=3)

n_classes = 8

print('Evaluation of Model 1: Сategorical Focal Jaccard Loss')
print_mean_iou(n_classes, test_pred_batch_model_1_argmax, test_mask_batch_argmax)

print('Evaluation of Model 2: Categorical CE Loss')
print_mean_iou(n_classes, test_pred_batch_model_2_argmax, test_mask_batch_argmax)

print('Evaluation of Model 3: Categorical Focal Dice Loss')
print_mean_iou(n_classes, test_pred_batch_model_3_argmax, test_mask_batch_argmax)
# Out:
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 1s 794ms/step
# Evaluation of Model 1: Сategorical Focal Jaccard Loss
# Mean IoU = 0.6408936
# Evaluation of Model 2: Categorical CE Loss
# Mean IoU = 0.6369012
# Evaluation of Model 3: Categorical Focal Dice Loss
# Mean IoU = 0.63136595

# %%
fig, axis = plt.subplots(test_image_batch.shape[0]-1, 6)
fig.set_figwidth(15)
fig.set_figheight(30)

for img_num in range(test_image_batch.shape[0]-1):   
    
    axis[img_num][0].imshow(test_image_batch[img_num][:,:,0])
    axis[img_num][0].set_title('Test_Image_Ch=1', fontsize = 6)
    axis[img_num][0].axes.xaxis.set_visible(False)
    axis[img_num][0].axes.yaxis.set_visible(False)

    axis[img_num][1].imshow(test_image_batch[img_num][:,:,1])
    axis[img_num][1].set_title('Test_Image_Ch=2', fontsize = 6)
    axis[img_num][1].axes.xaxis.set_visible(False)
    axis[img_num][1].axes.yaxis.set_visible(False)

    axis[img_num][2].imshow(test_mask_batch_argmax[img_num])
    axis[img_num][2].set_title("Testing Label", fontsize = 6)
    axis[img_num][2].axes.xaxis.set_visible(False)
    axis[img_num][2].axes.yaxis.set_visible(False)

    axis[img_num][3].imshow(test_pred_batch_model_1_argmax[img_num])
    axis[img_num][3].set_title("Prediction on test image Focal Jaccard Loss", fontsize = 6)
    axis[img_num][3].axes.xaxis.set_visible(False)
    axis[img_num][3].axes.yaxis.set_visible(False)

    axis[img_num][4].imshow(test_pred_batch_model_2_argmax[img_num])
    axis[img_num][4].set_title("Prediction on test image CE Loss", fontsize = 6)
    axis[img_num][4].axes.xaxis.set_visible(False)
    axis[img_num][4].axes.yaxis.set_visible(False)

    axis[img_num][5].imshow(test_pred_batch_model_3_argmax[img_num])
    axis[img_num][5].set_title("Prediction on test image Focal Dice Loss", fontsize = 6)
    axis[img_num][5].axes.xaxis.set_visible(False)
    axis[img_num][5].axes.yaxis.set_visible(False)
    
plt.show()
